# %%
from selenium import webdriver as wb
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import requests as req

# %%
# 테스트
driver = wb.Chrome()
url = 'http://www.kyobobook.co.kr/bestSellerNew/bestseller.laf?orderClick=d79'
driver.get(url)
soup = bs(driver.page_source, 'lxml')
rank = soup.select('.rank')
title = soup.select('.title > a > strong')

rank_list = []
title_list = []

for i in range(len(rank)):
    rank_list.append(rank[i].text)
    title_list.append(title[i].text)
    
dic = {'순위' : rank_list, '책제목' : title_list}
df = pd.DataFrame(dic)
df.set_index('순위', inplace=True)
print(df)
# Out:
#                                                   책제목
# 순위
# 1                                        트렌드 코리아 2022
# 2                              흔한남매. 9(양장본 HardCover)
# 3                                          거꾸로 읽는 세계사
# 4                                         소크라테스 익스프레스
# 5                          미드나잇 라이브러리(25만부 기념 퍼플 에디션)
# 6                             불편한 편의점(15만부 기념 윈터 에디션)
# 7                                            NFT 레볼루션
# 8                    웰씽킹(Wealthinking)(양장본 HardCover)
# 9                                           거인의 포트폴리오
# 10                                         달러구트 꿈 백화점
# 11                                           그냥 하지 말라
# 12  달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)(양장본 Har...
# 13                        흔한남매 겨울밤 대소동(양장본 HardCover)
# 14                                      달러구트 꿈 백화점. 2
# 15                                        이어령의 마지막 수업
# 16                                            오은영의 화해
# 17                                      원피스. 100: 패왕색
# 18                                          오십에 읽는 논어
# 19                   이상한 과자 가게 전천당. 12(양장본 HardCover)
# 20                                          주식투자 절대원칙

# %%
# 베스트셀러(YES24)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=yes24'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_yes = soup.select('ol.basic>li>dl>dt>a')
title_list_yes = []
rank_list_yes = []
for i in range(len(title_yes)):
    rank_list_yes.append(i+1)
    title_list_yes.append(title_yes[i].text)
dic = {'순위':rank_list_yes,'책제목':title_list_yes}
df_yes = pd.DataFrame(dic)
#df_yes.set_index('순위', inplace=True)
df_yes
# Out:
#     순위                          책제목
# 0    1                      이순신의 바다
# 1    2                       흔한남매 9
# 2    3                 트렌드 코리아 2022
# 3    4                      불편한 편의점
# 4    5                    거인의 포트폴리오
# 5    6                          웰씽킹
# 6    7                   미드나잇 라이브러리
# 7    8                   거꾸로 읽는 세계사
# 8    9       네모아저씨의 페이퍼 블레이드 4 프런티어
# 9   10                 흔한남매 겨울밤 대소동
# 10  11                      달콩이네 떡집
# 11  12                 달러구트 꿈 백화점 2
# 12  13                      오은영의 화해
# 13  14                개미 5년, 세후 55억
# 14  15              설민석의 세계사 대모험 11
# 15  16                종목 선정 나에게 물어봐
# 16  17                   달러구트 꿈 백화점
# 17  18                  소크라테스 익스프레스
# 18  19                     NFT 레볼루션
# 19  20                          눈아이
# 20  21                  어떻게 말해줘야 할까
# 21  22                    오십에 읽는 논어
# 22  23             김대리의 쉽게 뜨는 요즘 니트
# 23  24  딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 24  25                 흔한남매 과학탐험대 3

# %%
# 베스트셀러(교보문고)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=kyobo'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_kyobo = soup.select('ol.basic>li>dl>dt>a')
title_list_kyobo = []
rank_list_kyobo = []
for i in range(len(title_kyobo)):
    rank_list_kyobo.append(i+1)
    title_list_kyobo.append(title_kyobo[i].text)
dic = {'순위':rank_list_kyobo,'책제목':title_list_kyobo}
df_kyobo = pd.DataFrame(dic)
#df_kyobo.set_index('순위', inplace=True)
df_kyobo
# Out:
#     순위                책제목
# 0    1       트렌드 코리아 2022
# 1    2            불편한 편의점
# 2    3        소크라테스 익스프레스
# 3    4             흔한남매 9
# 4    5                웰씽킹
# 5    6            이순신의 바다
# 6    7     작은 별이지만 빛나고 있어
# 7    8         거꾸로 읽는 세계사
# 8    9           NFT 레볼루션
# 9   10         미드나잇 라이브러리
# 10  11          거인의 포트폴리오
# 11  12           하루공부 365
# 12  13         달러구트 꿈 백화점
# 13  14  내 영혼을 다독이는 관계 심리학
# 14  15  인생의 변화는 말투에서 시작된다
# 15  16           그냥, 그렇다고
# 16  17      개미 5년, 세후 55억
# 17  18            오은영의 화해
# 18  19   김대리의 쉽게 뜨는 요즘 니트
# 19  20   아무런 대가 없이 건네는 다정
# 20  21           그냥 하지 말라
# 21  22       달러구트 꿈 백화점 2
# 22  23            날마다 만우절
# 23  24          NFT 사용설명서
# 24  25           눈치 없는 돌쇠

# %%
# 베스트셀러(알라딘)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=aladdin'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_din = soup.select('ol.basic>li>dl>dt>a')
title_list_din = []
rank_list_din = []
for i in range(len(title_din)):
    rank_list_din.append(i+1)
    title_list_din.append(title_din[i].text)
dic = {'순위':rank_list_din,'책제목':title_list_din}
df_din = pd.DataFrame(dic)
#df_din.set_index('순위', inplace=True)
df_din
# Out:
#     순위                                    책제목
# 0    1                              귀멸의 칼날 외전
# 1    2                                    웰씽킹
# 2    3                          한 게으른 시인의 이야기
# 3    4                             거꾸로 읽는 세계사
# 4    5                       김대리의 쉽게 뜨는 요즘 니트
# 5    6                                  계절 산문
# 6    7                             도쿄 리벤저스 17
# 7    8                             도쿄 리벤저스 18
# 8    9                            소크라테스 익스프레스
# 9   10                           트렌드 코리아 2022
# 10  11                                이순신의 바다
# 11  12                                불편한 편의점
# 12  13                                   밝은 밤
# 13  14                              NFT 사용설명서
# 14  15            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 15  16                             달러구트 꿈 백화점
# 16  17                                체인소 맨 9
# 17  18                     요한 제바스티안 바흐 교회 칸타타
# 18  19                                라이온의 간식
# 19  20                          개미 5년, 세후 55억
# 20  21  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 21  22                               그냥 하지 말라
# 22  23                                오은영의 화해
# 23  24                           달러구트 꿈 백화점 2
# 24  25                        365일 명화 일력(스프링)

# %%
# 베스트셀러(인터파크도서)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=bookpark'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_park = soup.select('ol.basic>li>dl>dt>a')
title_list_park = []
rank_list_park = []
for i in range(len(title_park)):
    rank_list_park.append(i+1)
    title_list_park.append(title_park[i].text)
dic = {'순위':rank_list_park,'책제목':title_list_park}
df_park = pd.DataFrame(dic)
#df_park.set_index('순위', inplace=True)
df_park
# Out:
#     순위                                    책제목
# 0    1                                불편한 편의점
# 1    2                           트렌드 코리아 2022
# 2    3                             거꾸로 읽는 세계사
# 3    4                                이순신의 바다
# 4    5                                 흔한남매 9
# 5    6                          개미 5년, 세후 55억
# 6    7                                리딩지저스 1
# 7    8                           달러구트 꿈 백화점 2
# 8    9                                오은영의 화해
# 9   10                            소크라테스 익스프레스
# 10  11                                    웰씽킹
# 11  12                         작은 별이지만 빛나고 있어
# 12  13                             달러구트 꿈 백화점
# 13  14                          종목 선정 나에게 물어봐
# 14  15                             미드나잇 라이브러리
# 15  16                              오십에 읽는 논어
# 16  17                              거인의 포트폴리오
# 17  18                              NFT 사용설명서
# 18  19                       아직 오지 않은 날들을 위하여
# 19  20                               NFT 레볼루션
# 20  21                           부자 아빠 가난한 아빠
# 21  22                               하루공부 365
# 22  23                        설민석의 세계사 대모험 11
# 23  24  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 24  25                             달러구트 꿈 백화점

# %%
# 베스트셀러(영풍문고)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=ypbooks'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_yp = soup.select('ol.basic>li>dl>dt>a')
title_list_yp = []
rank_list_yp = []
for i in range(len(title_yp)):
    rank_list_yp.append(i+1)
    title_list_yp.append(title_yp[i].text)
dic = {'순위':rank_list_yp,'책제목':title_list_yp}
df_yp = pd.DataFrame(dic)
#df_yp.set_index('순위', inplace=True)
df_yp
# Out:
#     순위                       책제목
# 0    1                    흔한남매 9
# 1    2              트렌드 코리아 2022
# 2    3                   불편한 편의점
# 3    4                달러구트 꿈 백화점
# 4    5  오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 5    6              흔한남매 겨울밤 대소동
# 6    7                미드나잇 라이브러리
# 7    8              달러구트 꿈 백화점 2
# 8    9                 오십에 읽는 논어
# 9   10                거꾸로 읽는 세계사
# 10  11                  NFT 레볼루션
# 11  12                   원피스 100
# 12  13                   오은영의 화해
# 13  14               소크라테스 익스프레스
# 14  15                       웰씽킹
# 15  16              부자 아빠 가난한 아빠
# 16  17        햇빛은 찬란하고 인생은 귀하니까요
# 17  18                 귀멸의 칼날 외전
# 18  19                  크리스마스 피그
# 19  20          이상한 과자 가게 전천당 12
# 20  21              세계미래보고서 2022
# 21  22                  그냥 하지 말라
# 22  23                 거인의 포트폴리오
# 23  24                달러구트 꿈 백화점
# 24  25           이상한 과자 가게 전천당 1

# %%
# 스테디셀러 (알라딘)
driver = wb.Chrome()
url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&BestType=SteadySeller'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_steady = soup.select('.bo3')
title_list_steady = []
rank_list_steady = []
for i in range(len(title_steady)):
    title_list_steady.append(title_steady[i].text)
    rank_list_steady.append(i+1)
dic = {'번호':rank_list_steady,'책제목':title_list_steady}
df = pd.DataFrame(dic)
df.set_index('번호', inplace=True)
df
# Out:
#                                                   책제목
# 번호
# 1                         해커스 토익 기출 보카 TOEIC VOCA 단어장
# 2          ETS 토익 정기시험 기출문제집 1000 Vol. 2 Reading (리딩)
# 3       ETS 토익 정기시험 기출문제집 1000 Vol. 2 Listening (리스닝)
# 4                                             오은영의 화해
# 5                                               인간 실격
# 6                        부자 아빠 가난한 아빠 1 (20주년 특별 기념판)
# 7                                           죽음의 수용소에서
# 8                                                코스모스
# 9                                             밤의 여행자들
# 10                                 우리가 빛의 속도로 갈 수 없다면
# 11                               해커스 토익 RC 리딩 READING
# 12                                            부의 추월차선
# 13                               돈, 뜨겁게 사랑하고 차갑게 다루어라
# 14                                돈의 속성 (150쇄 기념 에디션)
# 15                                           아몬드 (양장)
# 16                                       데일 카네기 인간관계론
# 17                                      여름은 오래 그곳에 남아
# 18                                            만복이네 떡집
# 19                            해커스 토익 LC 리스닝 LISTENING
# 20                                               사피엔스
# 21                                            이기적 유전자
# 22                                      체리새우 : 비밀글입니다
# 23                                        김락희의 인체 드로잉
# 24               ETS 토익 정기시험 기출문제집 1000 Vol.1 Reading
# 25                                   해커스 토익 스타트 리딩 RC
# 26                                            팥빙수의 전설
# 27                                          푸른 사자 와니니
# 28                                            장군이네 떡집
# 29                                                데미안
# 30                                          아몬드 (반양장)
# 31  해커스 토익 실전 1000제 1 RC 리딩 문제집 (Hackers TOEIC Rea...
# 32                                              파친코 1
# 33                                              파친코 2
# 34                                              소원 떡집
# 35                               키득키득 사운드북 : 동물 오케스트라
# 36                                    이상한 과자 가게 전천당 1
# 37                               지적 대화를 위한 넓고 얕은 지식 1
# 38                                      세계를 건너 너에게 갈게
# 39                                       상처받은 내면아이 치유
# 40             ETS 토익 정기시험 기출문제집 1000 Vol.1 Listening
# 41  해커스 토익 실전 1000제 1 LC 리스닝 문제집 (Hackers TOEIC Li...
# 42                                         아홉 살 마음 사전
# 43                                           정의란 무엇인가
# 44                                       고양이 해결사 깜냥 1
# 45                                 옷소매 붉은 끝동 세트 - 전2권
# 46                                           이파라파냐무냐무
# 47                                             부의 인문학
# 48                                  해커스 토익 스타트 리스닝 LC
# 49                                          페인트 (반양장)
# 50                            우리 아기 오감발달 시끌벅적 정글 사운드북

# %%
# 베스트신간도서(교보문고)
driver = wb.Chrome()
url = 'http://www.kyobobook.co.kr/newproduct/newProductList.laf'
driver.get(url)
soup = bs(driver.page_source, 'lxml')
time.sleep(1)

btn = driver.find_element_by_css_selector('#showcaseNew > div:nth-child(2) > div.list_paging > ul > li:nth-child(2) > a')

title_list_new = []
rank_list_new = []
title_new = soup.select('.title>a>strong')

 
for i in range(len(title_new)):
    title_list_new.append(title_new[i].text)
    rank_list_new.append(i+1)

#btn.click()
#time.sleep(5)

#title_new = soup.select('.title>a>strong')
#for i in range(len(title_new)):
    #title_list_new.append(title_new[i].text)
    #rank_list_new.append(i+1)

dic = {'번호':rank_list_new,'책제목':title_list_new}
df = pd.DataFrame(dic)
df.set_index('번호', inplace=True)
df
# Out:
# <ipython-input-13-bfd923b24811>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   btn = driver.find_element_by_css_selector('#showcaseNew > div:nth-child(2) > div.list_paging > ul > li:nth-child(2) > a')
#                                  책제목
# 번호
# 1                            이순신의 바다
# 2     호찌냥찌 새로운 이야기 세트(양장본 HardCover)
# 3                  코지마 히데오의 창작하는 유전자
# 4                      물고기는 존재하지 않는다
# 5                               비만백서
# 6   웰씽킹(Wealthinking)(양장본 HardCover)
# 7                           허상의 어릿광대
# 8                우리는 기후 변화에도 적응할 것이다
# 9                         박물관 옆 사회교실
# 10                 점검(양장본 HardCover)
# 11                            팬데믹 머니
# 12         흔한남매 신나는 2022 따라쓰기 벽걸이 달력
# 13                  척추 관절 도침치료가 정답이다
# 14            지속가능한 미래를 위한 기후변화 데이터북
# 15                            퀀텀의 세계
# 16           어떤 계모님의 메르헨. 3(초호화 한정판)
# 17                          차근차근 클래식
# 18                       화장실 벽에 쓴 낙서
# 19                          2만 번의 통찰
# 20              KBS 한국어능력시험 기출문제. 17

# %%
df_all=pd.concat([df_yes,df_kyobo,df_din,df_park,df_yp])
pd.set_option('display.max_row',200)
df_all
# Out:
#     순위                                    책제목
# 0    1                                이순신의 바다
# 1    2                                 흔한남매 9
# 2    3                           트렌드 코리아 2022
# 3    4                                불편한 편의점
# 4    5                              거인의 포트폴리오
# 5    6                                    웰씽킹
# 6    7                             미드나잇 라이브러리
# 7    8                             거꾸로 읽는 세계사
# 8    9                 네모아저씨의 페이퍼 블레이드 4 프런티어
# 9   10                           흔한남매 겨울밤 대소동
# 10  11                                달콩이네 떡집
# 11  12                           달러구트 꿈 백화점 2
# 12  13                                오은영의 화해
# 13  14                          개미 5년, 세후 55억
# 14  15                        설민석의 세계사 대모험 11
# 15  16                          종목 선정 나에게 물어봐
# 16  17                             달러구트 꿈 백화점
# 17  18                            소크라테스 익스프레스
# 18  19                               NFT 레볼루션
# 19  20                                    눈아이
# 20  21                            어떻게 말해줘야 할까
# 21  22                              오십에 읽는 논어
# 22  23                       김대리의 쉽게 뜨는 요즘 니트
# 23  24            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 24  25                           흔한남매 과학탐험대 3
# 0    1                           트렌드 코리아 2022
# 1    2                                불편한 편의점
# 2    3                            소크라테스 익스프레스
# 3    4                                 흔한남매 9
# 4    5                                    웰씽킹
# 5    6                                이순신의 바다
# 6    7                         작은 별이지만 빛나고 있어
# 7    8                             거꾸로 읽는 세계사
# 8    9                               NFT 레볼루션
# 9   10                             미드나잇 라이브러리
# 10  11                              거인의 포트폴리오
# 11  12                               하루공부 365
# 12  13                             달러구트 꿈 백화점
# 13  14                      내 영혼을 다독이는 관계 심리학
# 14  15                      인생의 변화는 말투에서 시작된다
# 15  16                               그냥, 그렇다고
# 16  17                          개미 5년, 세후 55억
# 17  18                                오은영의 화해
# 18  19                       김대리의 쉽게 뜨는 요즘 니트
# 19  20                       아무런 대가 없이 건네는 다정
# 20  21                               그냥 하지 말라
# 21  22                           달러구트 꿈 백화점 2
# 22  23                                날마다 만우절
# 23  24                              NFT 사용설명서
# 24  25                               눈치 없는 돌쇠
# 0    1                              귀멸의 칼날 외전
# 1    2                                    웰씽킹
# 2    3                          한 게으른 시인의 이야기
# 3    4                             거꾸로 읽는 세계사
# 4    5                       김대리의 쉽게 뜨는 요즘 니트
# 5    6                                  계절 산문
# 6    7                             도쿄 리벤저스 17
# 7    8                             도쿄 리벤저스 18
# 8    9                            소크라테스 익스프레스
# 9   10                           트렌드 코리아 2022
# 10  11                                이순신의 바다
# 11  12                                불편한 편의점
# 12  13                                   밝은 밤
# 13  14                              NFT 사용설명서
# 14  15            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 15  16                             달러구트 꿈 백화점
# 16  17                                체인소 맨 9
# 17  18                     요한 제바스티안 바흐 교회 칸타타
# 18  19                                라이온의 간식
# 19  20                          개미 5년, 세후 55억
# 20  21  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 21  22                               그냥 하지 말라
# 22  23                                오은영의 화해
# 23  24                           달러구트 꿈 백화점 2
# 24  25                        365일 명화 일력(스프링)
# 0    1                                불편한 편의점
# 1    2                           트렌드 코리아 2022
# 2    3                             거꾸로 읽는 세계사
# 3    4                                이순신의 바다
# 4    5                                 흔한남매 9
# 5    6                          개미 5년, 세후 55억
# 6    7                                리딩지저스 1
# 7    8                           달러구트 꿈 백화점 2
# 8    9                                오은영의 화해
# 9   10                            소크라테스 익스프레스
# 10  11                                    웰씽킹
# 11  12                         작은 별이지만 빛나고 있어
# 12  13                             달러구트 꿈 백화점
# 13  14                          종목 선정 나에게 물어봐
# 14  15                             미드나잇 라이브러리
# 15  16                              오십에 읽는 논어
# 16  17                              거인의 포트폴리오
# 17  18                              NFT 사용설명서
# 18  19                       아직 오지 않은 날들을 위하여
# 19  20                               NFT 레볼루션
# 20  21                           부자 아빠 가난한 아빠
# 21  22                               하루공부 365
# 22  23                        설민석의 세계사 대모험 11
# 23  24  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 24  25                             달러구트 꿈 백화점
# 0    1                                 흔한남매 9
# 1    2                           트렌드 코리아 2022
# 2    3                                불편한 편의점
# 3    4                             달러구트 꿈 백화점
# 4    5               오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 5    6                           흔한남매 겨울밤 대소동
# 6    7                             미드나잇 라이브러리
# 7    8                           달러구트 꿈 백화점 2
# 8    9                              오십에 읽는 논어
# 9   10                             거꾸로 읽는 세계사
# 10  11                               NFT 레볼루션
# 11  12                                원피스 100
# 12  13                                오은영의 화해
# 13  14                            소크라테스 익스프레스
# 14  15                                    웰씽킹
# 15  16                           부자 아빠 가난한 아빠
# 16  17                     햇빛은 찬란하고 인생은 귀하니까요
# 17  18                              귀멸의 칼날 외전
# 18  19                               크리스마스 피그
# 19  20                       이상한 과자 가게 전천당 12
# 20  21                           세계미래보고서 2022
# 21  22                               그냥 하지 말라
# 22  23                              거인의 포트폴리오
# 23  24                             달러구트 꿈 백화점
# 24  25                        이상한 과자 가게 전천당 1

# %%
# df_all 에서 책제목이 5개 이상있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() >= 5]
# df_all 에서 책제목이 4개 있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() == 4]
# df_all 에서 책제목이 3개 있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() == 3]
# df_all 에서 책제목이 2개 있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() == 2]
# df_all 에서 책제목이 1개 있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() == 1]
# Out:
# 아무런 대가 없이 건네는 다정            1
# 한 게으른 시인의 이야기               1
# 인생의 변화는 말투에서 시작된다           1
# 리딩지저스 1                     1
# 아직 오지 않은 날들을 위하여            1
# 밝은 밤                        1
# 도쿄 리벤저스 17                  1
# 365일 명화 일력(스프링)             1
# 어떻게 말해줘야 할까                 1
# 내 영혼을 다독이는 관계 심리학           1
# 이상한 과자 가게 전천당 1             1
# 그냥, 그렇다고                    1
# 세계미래보고서 2022                1
# 눈아이                         1
# 날마다 만우절                     1
# 체인소 맨 9                     1
# 달콩이네 떡집                     1
# 도쿄 리벤저스 18                  1
# 요한 제바스티안 바흐 교회 칸타타          1
# 크리스마스 피그                    1
# 햇빛은 찬란하고 인생은 귀하니까요          1
# 흔한남매 과학탐험대 3                1
# 오늘 밤, 세계에서 이 사랑이 사라진다 해도    1
# 이상한 과자 가게 전천당 12            1
# 원피스 100                     1
# 계절 산문                       1
# 눈치 없는 돌쇠                    1
# 라이온의 간식                     1
# 네모아저씨의 페이퍼 블레이드 4 프런티어      1
# Name: 책제목, dtype: int64

# %%
df_all['책제목'].value_counts()[df_all['책제목'].value_counts()>=5]
# Out:
# 달러구트 꿈 백화점      7
# 불편한 편의점         5
# 오은영의 화해         5
# 트렌드 코리아 2022    5
# 거꾸로 읽는 세계사      5
# 소크라테스 익스프레스     5
# 달러구트 꿈 백화점 2    5
# 웰씽킹             5
# Name: 책제목, dtype: int64

# %%
df_all
# Out:
#     순위                                    책제목
# 0    1                                이순신의 바다
# 1    2                                 흔한남매 9
# 2    3                           트렌드 코리아 2022
# 3    4                                불편한 편의점
# 4    5                              거인의 포트폴리오
# 5    6                                    웰씽킹
# 6    7                             미드나잇 라이브러리
# 7    8                             거꾸로 읽는 세계사
# 8    9                 네모아저씨의 페이퍼 블레이드 4 프런티어
# 9   10                           흔한남매 겨울밤 대소동
# 10  11                                달콩이네 떡집
# 11  12                           달러구트 꿈 백화점 2
# 12  13                                오은영의 화해
# 13  14                          개미 5년, 세후 55억
# 14  15                        설민석의 세계사 대모험 11
# 15  16                          종목 선정 나에게 물어봐
# 16  17                             달러구트 꿈 백화점
# 17  18                            소크라테스 익스프레스
# 18  19                               NFT 레볼루션
# 19  20                                    눈아이
# 20  21                            어떻게 말해줘야 할까
# 21  22                              오십에 읽는 논어
# 22  23                       김대리의 쉽게 뜨는 요즘 니트
# 23  24            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 24  25                           흔한남매 과학탐험대 3
# 0    1                           트렌드 코리아 2022
# 1    2                                불편한 편의점
# 2    3                            소크라테스 익스프레스
# 3    4                                 흔한남매 9
# 4    5                                    웰씽킹
# 5    6                                이순신의 바다
# 6    7                         작은 별이지만 빛나고 있어
# 7    8                             거꾸로 읽는 세계사
# 8    9                               NFT 레볼루션
# 9   10                             미드나잇 라이브러리
# 10  11                              거인의 포트폴리오
# 11  12                               하루공부 365
# 12  13                             달러구트 꿈 백화점
# 13  14                      내 영혼을 다독이는 관계 심리학
# 14  15                      인생의 변화는 말투에서 시작된다
# 15  16                               그냥, 그렇다고
# 16  17                          개미 5년, 세후 55억
# 17  18                                오은영의 화해
# 18  19                       김대리의 쉽게 뜨는 요즘 니트
# 19  20                       아무런 대가 없이 건네는 다정
# 20  21                               그냥 하지 말라
# 21  22                           달러구트 꿈 백화점 2
# 22  23                                날마다 만우절
# 23  24                              NFT 사용설명서
# 24  25                               눈치 없는 돌쇠
# 0    1                              귀멸의 칼날 외전
# 1    2                                    웰씽킹
# 2    3                          한 게으른 시인의 이야기
# 3    4                             거꾸로 읽는 세계사
# 4    5                       김대리의 쉽게 뜨는 요즘 니트
# 5    6                                  계절 산문
# 6    7                             도쿄 리벤저스 17
# 7    8                             도쿄 리벤저스 18
# 8    9                            소크라테스 익스프레스
# 9   10                           트렌드 코리아 2022
# 10  11                                이순신의 바다
# 11  12                                불편한 편의점
# 12  13                                   밝은 밤
# 13  14                              NFT 사용설명서
# 14  15            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 15  16                             달러구트 꿈 백화점
# 16  17                                체인소 맨 9
# 17  18                     요한 제바스티안 바흐 교회 칸타타
# 18  19                                라이온의 간식
# 19  20                          개미 5년, 세후 55억
# 20  21  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 21  22                               그냥 하지 말라
# 22  23                                오은영의 화해
# 23  24                           달러구트 꿈 백화점 2
# 24  25                        365일 명화 일력(스프링)
# 0    1                                불편한 편의점
# 1    2                           트렌드 코리아 2022
# 2    3                             거꾸로 읽는 세계사
# 3    4                                이순신의 바다
# 4    5                                 흔한남매 9
# 5    6                          개미 5년, 세후 55억
# 6    7                                리딩지저스 1
# 7    8                           달러구트 꿈 백화점 2
# 8    9                                오은영의 화해
# 9   10                            소크라테스 익스프레스
# 10  11                                    웰씽킹
# 11  12                         작은 별이지만 빛나고 있어
# 12  13                             달러구트 꿈 백화점
# 13  14                          종목 선정 나에게 물어봐
# 14  15                             미드나잇 라이브러리
# 15  16                              오십에 읽는 논어
# 16  17                              거인의 포트폴리오
# 17  18                              NFT 사용설명서
# 18  19                       아직 오지 않은 날들을 위하여
# 19  20                               NFT 레볼루션
# 20  21                           부자 아빠 가난한 아빠
# 21  22                               하루공부 365
# 22  23                        설민석의 세계사 대모험 11
# 23  24  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 24  25                             달러구트 꿈 백화점
# 0    1                                 흔한남매 9
# 1    2                           트렌드 코리아 2022
# 2    3                                불편한 편의점
# 3    4                             달러구트 꿈 백화점
# 4    5               오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 5    6                           흔한남매 겨울밤 대소동
# 6    7                             미드나잇 라이브러리
# 7    8                           달러구트 꿈 백화점 2
# 8    9                              오십에 읽는 논어
# 9   10                             거꾸로 읽는 세계사
# 10  11                               NFT 레볼루션
# 11  12                                원피스 100
# 12  13                                오은영의 화해
# 13  14                            소크라테스 익스프레스
# 14  15                                    웰씽킹
# 15  16                           부자 아빠 가난한 아빠
# 16  17                     햇빛은 찬란하고 인생은 귀하니까요
# 17  18                              귀멸의 칼날 외전
# 18  19                               크리스마스 피그
# 19  20                       이상한 과자 가게 전천당 12
# 20  21                           세계미래보고서 2022
# 21  22                               그냥 하지 말라
# 22  23                              거인의 포트폴리오
# 23  24                             달러구트 꿈 백화점
# 24  25                        이상한 과자 가게 전천당 1
