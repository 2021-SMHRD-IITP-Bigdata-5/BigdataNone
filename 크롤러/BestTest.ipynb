# %%
from selenium import webdriver as wb
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import requests as req

# %%
# 테스트
driver = wb.Chrome()
url = 'http://www.kyobobook.co.kr/bestSellerNew/bestseller.laf?orderClick=d79'
driver.get(url)
soup = bs(driver.page_source, 'lxml')
rank = soup.select('.rank')
title = soup.select('.title > a > strong')

rank_list = []
title_list = []

for i in range(len(rank)):
    rank_list.append(rank[i].text)
    title_list.append(title[i].text)
    
dic = {'순위' : rank_list, '책제목' : title_list}
df = pd.DataFrame(dic)
df.set_index('순위', inplace=True)
print(df)
# Out:
#                                                   책제목
# 순위
# 1                                        트렌드 코리아 2022
# 2                              흔한남매. 9(양장본 HardCover)
# 3                             불편한 편의점(15만부 기념 윈터 에디션)
# 4                                         소크라테스 익스프레스
# 5                          미드나잇 라이브러리(25만부 기념 퍼플 에디션)
# 6                                          거꾸로 읽는 세계사
# 7                                            NFT 레볼루션
# 8                    웰씽킹(Wealthinking)(양장본 HardCover)
# 9                                           거인의 포트폴리오
# 10  달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)(양장본 Har...
# 11                                         달러구트 꿈 백화점
# 12                                      달러구트 꿈 백화점. 2
# 13                        흔한남매 겨울밤 대소동(양장본 HardCover)
# 14                                           그냥 하지 말라
# 15                                            오은영의 화해
# 16                                        이어령의 마지막 수업
# 17                                            이순신의 바다
# 18                          나는 장사의 신이다(양장본 HardCover)
# 19                                          오십에 읽는 논어
# 20         오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)

# %%
# 베스트셀러(YES24)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=yes24'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_yes = soup.select('ol.basic>li>dl>dt>a')
title_list_yes = []
rank_list_yes = []
for i in range(len(title_yes)):
    rank_list_yes.append(i+1)
    title_list_yes.append(title_yes[i].text)
dic = {'순위':rank_list_yes,'책제목':title_list_yes}
df_yes = pd.DataFrame(dic)
#df_yes.set_index('순위', inplace=True)
df_yes
# Out:
#     순위                          책제목
# 0    1                      이순신의 바다
# 1    2                       흔한남매 9
# 2    3                 트렌드 코리아 2022
# 3    4                      불편한 편의점
# 4    5                    거인의 포트폴리오
# 5    6                          웰씽킹
# 6    7                   미드나잇 라이브러리
# 7    8                   거꾸로 읽는 세계사
# 8    9       네모아저씨의 페이퍼 블레이드 4 프런티어
# 9   10                 흔한남매 겨울밤 대소동
# 10  11                      달콩이네 떡집
# 11  12                 달러구트 꿈 백화점 2
# 12  13                      오은영의 화해
# 13  14                개미 5년, 세후 55억
# 14  15              설민석의 세계사 대모험 11
# 15  16                종목 선정 나에게 물어봐
# 16  17                   달러구트 꿈 백화점
# 17  18                  소크라테스 익스프레스
# 18  19                     NFT 레볼루션
# 19  20                          눈아이
# 20  21                  어떻게 말해줘야 할까
# 21  22                    오십에 읽는 논어
# 22  23             김대리의 쉽게 뜨는 요즘 니트
# 23  24  딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 24  25                 흔한남매 과학탐험대 3

# %%
# 베스트셀러(교보문고)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=kyobo'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_kyobo = soup.select('ol.basic>li>dl>dt>a')
title_list_kyobo = []
rank_list_kyobo = []
for i in range(len(title_kyobo)):
    rank_list_kyobo.append(i+1)
    title_list_kyobo.append(title_kyobo[i].text)
dic = {'순위':rank_list_kyobo,'책제목':title_list_kyobo}
df_kyobo = pd.DataFrame(dic)
#df_kyobo.set_index('순위', inplace=True)
df_kyobo
# Out:
#     순위                책제목
# 0    1       트렌드 코리아 2022
# 1    2            불편한 편의점
# 2    3        소크라테스 익스프레스
# 3    4             흔한남매 9
# 4    5                웰씽킹
# 5    6            이순신의 바다
# 6    7     작은 별이지만 빛나고 있어
# 7    8         거꾸로 읽는 세계사
# 8    9           NFT 레볼루션
# 9   10         미드나잇 라이브러리
# 10  11          거인의 포트폴리오
# 11  12           하루공부 365
# 12  13         달러구트 꿈 백화점
# 13  14  내 영혼을 다독이는 관계 심리학
# 14  15  인생의 변화는 말투에서 시작된다
# 15  16           그냥, 그렇다고
# 16  17      개미 5년, 세후 55억
# 17  18            오은영의 화해
# 18  19   김대리의 쉽게 뜨는 요즘 니트
# 19  20   아무런 대가 없이 건네는 다정
# 20  21           그냥 하지 말라
# 21  22       달러구트 꿈 백화점 2
# 22  23            날마다 만우절
# 23  24          NFT 사용설명서
# 24  25           눈치 없는 돌쇠

# %%
# 베스트셀러(알라딘)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=aladdin'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_din = soup.select('ol.basic>li>dl>dt>a')
title_list_din = []
rank_list_din = []
for i in range(len(title_din)):
    rank_list_din.append(i+1)
    title_list_din.append(title_din[i].text)
dic = {'순위':rank_list_din,'책제목':title_list_din}
df_din = pd.DataFrame(dic)
#df_din.set_index('순위', inplace=True)
df_din
# Out:
#     순위                                    책제목
# 0    1                              귀멸의 칼날 외전
# 1    2                                    웰씽킹
# 2    3                          한 게으른 시인의 이야기
# 3    4                             거꾸로 읽는 세계사
# 4    5                       김대리의 쉽게 뜨는 요즘 니트
# 5    6                                  계절 산문
# 6    7                             도쿄 리벤저스 17
# 7    8                             도쿄 리벤저스 18
# 8    9                            소크라테스 익스프레스
# 9   10                           트렌드 코리아 2022
# 10  11                                이순신의 바다
# 11  12                                불편한 편의점
# 12  13                                   밝은 밤
# 13  14                              NFT 사용설명서
# 14  15            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 15  16                             달러구트 꿈 백화점
# 16  17                                체인소 맨 9
# 17  18                     요한 제바스티안 바흐 교회 칸타타
# 18  19                                라이온의 간식
# 19  20                          개미 5년, 세후 55억
# 20  21  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 21  22                               그냥 하지 말라
# 22  23                                오은영의 화해
# 23  24                           달러구트 꿈 백화점 2
# 24  25                        365일 명화 일력(스프링)

# %%
# 베스트셀러(인터파크도서)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=bookpark'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_park = soup.select('ol.basic>li>dl>dt>a')
title_list_park = []
rank_list_park = []
for i in range(len(title_park)):
    rank_list_park.append(i+1)
    title_list_park.append(title_park[i].text)
dic = {'순위':rank_list_park,'책제목':title_list_park}
df_park = pd.DataFrame(dic)
#df_park.set_index('순위', inplace=True)
df_park
# Out:
#     순위                                    책제목
# 0    1                                불편한 편의점
# 1    2                           트렌드 코리아 2022
# 2    3                             거꾸로 읽는 세계사
# 3    4                                이순신의 바다
# 4    5                                 흔한남매 9
# 5    6                          개미 5년, 세후 55억
# 6    7                                리딩지저스 1
# 7    8                           달러구트 꿈 백화점 2
# 8    9                                오은영의 화해
# 9   10                            소크라테스 익스프레스
# 10  11                                    웰씽킹
# 11  12                         작은 별이지만 빛나고 있어
# 12  13                             달러구트 꿈 백화점
# 13  14                          종목 선정 나에게 물어봐
# 14  15                             미드나잇 라이브러리
# 15  16                              오십에 읽는 논어
# 16  17                              거인의 포트폴리오
# 17  18                              NFT 사용설명서
# 18  19                       아직 오지 않은 날들을 위하여
# 19  20                               NFT 레볼루션
# 20  21                           부자 아빠 가난한 아빠
# 21  22                               하루공부 365
# 22  23                        설민석의 세계사 대모험 11
# 23  24  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 24  25                             달러구트 꿈 백화점

# %%
# 베스트셀러(영풍문고)
driver = wb.Chrome()
url = 'https://book.naver.com/bestsell/bestseller_list.naver?cp=ypbooks'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_yp = soup.select('ol.basic>li>dl>dt>a')
title_list_yp = []
rank_list_yp = []
for i in range(len(title_yp)):
    rank_list_yp.append(i+1)
    title_list_yp.append(title_yp[i].text)
dic = {'순위':rank_list_yp,'책제목':title_list_yp}
df_yp = pd.DataFrame(dic)
#df_yp.set_index('순위', inplace=True)
df_yp
# Out:
#     순위                       책제목
# 0    1                    흔한남매 9
# 1    2              트렌드 코리아 2022
# 2    3                   불편한 편의점
# 3    4                달러구트 꿈 백화점
# 4    5  오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 5    6              흔한남매 겨울밤 대소동
# 6    7                미드나잇 라이브러리
# 7    8              달러구트 꿈 백화점 2
# 8    9                 오십에 읽는 논어
# 9   10                거꾸로 읽는 세계사
# 10  11                  NFT 레볼루션
# 11  12                   원피스 100
# 12  13                   오은영의 화해
# 13  14               소크라테스 익스프레스
# 14  15                       웰씽킹
# 15  16              부자 아빠 가난한 아빠
# 16  17        햇빛은 찬란하고 인생은 귀하니까요
# 17  18                 귀멸의 칼날 외전
# 18  19                  크리스마스 피그
# 19  20          이상한 과자 가게 전천당 12
# 20  21              세계미래보고서 2022
# 21  22                  그냥 하지 말라
# 22  23                 거인의 포트폴리오
# 23  24                달러구트 꿈 백화점
# 24  25           이상한 과자 가게 전천당 1

# %%
# 스테디셀러 (알라딘)
driver = wb.Chrome()
url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&BestType=SteadySeller'
driver.get(url)
soup = bs(driver.page_source, 'lxml')

title_steady = soup.select('.bo3')
title_list_steady = []
rank_list_steady = []
for i in range(len(title_steady)):
    title_list_steady.append(title_steady[i].text)
    rank_list_steady.append(i+1)
dic = {'번호':rank_list_steady,'책제목':title_list_steady}
df = pd.DataFrame(dic)
df.set_index('번호', inplace=True)
df
# Out:
#                                                   책제목
# 번호
# 1                         해커스 토익 기출 보카 TOEIC VOCA 단어장
# 2          ETS 토익 정기시험 기출문제집 1000 Vol. 2 Reading (리딩)
# 3       ETS 토익 정기시험 기출문제집 1000 Vol. 2 Listening (리스닝)
# 4                                             오은영의 화해
# 5                                               인간 실격
# 6                        부자 아빠 가난한 아빠 1 (20주년 특별 기념판)
# 7                                돈, 뜨겁게 사랑하고 차갑게 다루어라
# 8                                                코스모스
# 9                                  우리가 빛의 속도로 갈 수 없다면
# 10                                            밤의 여행자들
# 11                                            부의 추월차선
# 12                               해커스 토익 RC 리딩 READING
# 13                                          죽음의 수용소에서
# 14                                돈의 속성 (150쇄 기념 에디션)
# 15                                           아몬드 (양장)
# 16                                       데일 카네기 인간관계론
# 17                                            이기적 유전자
# 18                                      여름은 오래 그곳에 남아
# 19                                            만복이네 떡집
# 20                                               사피엔스
# 21                            해커스 토익 LC 리스닝 LISTENING
# 22                                      체리새우 : 비밀글입니다
# 23                                        김락희의 인체 드로잉
# 24               ETS 토익 정기시험 기출문제집 1000 Vol.1 Reading
# 25                                                데미안
# 26                                            장군이네 떡집
# 27                                          푸른 사자 와니니
# 28                                          아몬드 (반양장)
# 29                                   해커스 토익 스타트 리딩 RC
# 30                                    이상한 과자 가게 전천당 1
# 31                                            팥빙수의 전설
# 32                               키득키득 사운드북 : 동물 오케스트라
# 33  해커스 토익 실전 1000제 1 RC 리딩 문제집 (Hackers TOEIC Rea...
# 34                                              소원 떡집
# 35                                              파친코 1
# 36                               지적 대화를 위한 넓고 얕은 지식 1
# 37                                              파친코 2
# 38                                      세계를 건너 너에게 갈게
# 39                                       상처받은 내면아이 치유
# 40             ETS 토익 정기시험 기출문제집 1000 Vol.1 Listening
# 41                                 옷소매 붉은 끝동 세트 - 전2권
# 42  해커스 토익 실전 1000제 1 LC 리스닝 문제집 (Hackers TOEIC Li...
# 43                                           정의란 무엇인가
# 44                                         아홉 살 마음 사전
# 45                                             부의 인문학
# 46                                       고양이 해결사 깜냥 1
# 47                                          페인트 (반양장)
# 48                            우리 아기 오감발달 시끌벅적 정글 사운드북
# 49                               우리 아기 오감발달 동물농장 사운드북
# 50                                  해커스 토익 스타트 리스닝 LC

# %%
# 베스트신간도서(교보문고)
driver = wb.Chrome()
url = 'http://www.kyobobook.co.kr/newproduct/newProductList.laf?orderClick=Ca1'
driver.get(url)
soup = bs(driver.page_source, 'lxml')
time.sleep(1)

title_list_new = []
rank_list_new = []
author_list = []
publisher_list = []
date_list = []
img_list = []

title_new = soup.select('.title>a>strong')
author = soup.select('.author')
publisher = soup.select('.pub_info>span:nth-child(2)')
date = soup.select('.pub_info>span:nth-child(3)')
 
for i in range(len(title_new)):
    title_list_new.append(title_new[i].text)
    rank_list_new.append(i+1)
    author_list.append(author[i].text)
    publisher_list.append(publisher[i].text)
    date_list.append(date[i].text)

#btn.click()
#time.sleep(5)

#title_new = soup.select('.title>a>strong')
#for i in range(len(title_new)):
    #title_list_new.append(title_new[i].text)
    #rank_list_new.append(i+1)

dic = {'번호':rank_list_new,'책제목':title_list_new, '작가':author_list, '출판사':publisher_list, '출판일':date_list}
df = pd.DataFrame(dic)
df.set_index('번호', inplace=True)
df
# Out:
#                                                   책제목             작가  \
# 번호
# 1                           폭격기의 달이 뜨면(양장본 HardCover)          에릭 라슨
# 2                                    고정욱 삼국지 세트(전10권)            나관중
# 3                                               주식의 도          생존재테크
# 4                                          우리가 만난 아이들            이근아
# 5                                    하루를 48시간으로 사는 마법            이재은
# 6                                    발과 발목에 문제가 생겼습니다            서상교
# 7                              월간순정 노자키군. 13(소책자 한정판)  Izumi Tsubaki
# 8   그리스 로마 신화. 26: 아킬레우스와 헥토르의 운명을 건 대결(양장본 HardCo...            박시연
# 9           전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)(전8권)             싱숑
# 10                                            영롱보다 몽롱            허은실
# 11                                             예측의 역사      마틴 반 크레벨드
# 12                  신비아파트 고스트볼 Z 어둠의 퇴마사 덧셈과 뺄셈을 잡아라!      고은문화사 편집부
# 13                                            글래시스 로드            한지선
# 14             므레모사(현대문학 핀 시리즈 소설선 38)(양장본 HardCover)            김초엽
# 15              췌장암 담도암 완치설명서(연세대 의대 세브란스병원 메디컬 북스 8)            이동기
# 16                       까칠한 재석이가 돌아왔다(양장본 HardCover)            고정욱
# 17                                             오늘의 법칙         로버트 그린
# 18          모돌이 탐정 세트(한국만화걸작선 29)(양장본 HardCover)(전4권)            이우정
# 19                                              실직 도시            방준호
# 20                                     와처(책 읽는 샤미 12)            신은경
#
#           출판사             출판일
# 번호
# 1        생각의힘  2021년 12월 10일
# 2        애플북스  2022년 01월 07일
# 3      트러스트북스  2021년 12월 29일
# 4      위즈덤하우스  2021년 12월 22일
# 5      비즈니스북스  2021년 12월 17일
# 6        비타북스  2021년 12월 20일
# 7       학산문화사  2021년 12월 25일
# 8         아울북  2021년 12월 27일
# 9          비채  2022년 01월 20일
# 10      을유문화사  2021년 12월 10일
# 11        현암사  2021년 12월 15일
# 12      고은문화사  2021년 12월 15일
# 13     위즈덤하우스  2021년 12월 22일
# 14       현대문학  2021년 12월 25일
# 15       헬스조선  2021년 12월 10일
# 16       애플북스  2012년 07월 12일
# 17         까치  2021년 12월 15일
# 18  한국만화영상진흥원  2021년 12월 20일
# 19         부키  2021년 12월 20일
# 20        이지북  2022년 01월 02일

# %%
df_all=pd.concat([df_yes,df_kyobo,df_din,df_park,df_yp])
pd.set_option('display.max_row',200)
df_all
# Out:
#     순위                                    책제목
# 0    1                                이순신의 바다
# 1    2                                 흔한남매 9
# 2    3                           트렌드 코리아 2022
# 3    4                                불편한 편의점
# 4    5                              거인의 포트폴리오
# 5    6                                    웰씽킹
# 6    7                             미드나잇 라이브러리
# 7    8                             거꾸로 읽는 세계사
# 8    9                 네모아저씨의 페이퍼 블레이드 4 프런티어
# 9   10                           흔한남매 겨울밤 대소동
# 10  11                                달콩이네 떡집
# 11  12                           달러구트 꿈 백화점 2
# 12  13                                오은영의 화해
# 13  14                          개미 5년, 세후 55억
# 14  15                        설민석의 세계사 대모험 11
# 15  16                          종목 선정 나에게 물어봐
# 16  17                             달러구트 꿈 백화점
# 17  18                            소크라테스 익스프레스
# 18  19                               NFT 레볼루션
# 19  20                                    눈아이
# 20  21                            어떻게 말해줘야 할까
# 21  22                              오십에 읽는 논어
# 22  23                       김대리의 쉽게 뜨는 요즘 니트
# 23  24            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 24  25                           흔한남매 과학탐험대 3
# 0    1                           트렌드 코리아 2022
# 1    2                                불편한 편의점
# 2    3                            소크라테스 익스프레스
# 3    4                                 흔한남매 9
# 4    5                                    웰씽킹
# 5    6                                이순신의 바다
# 6    7                         작은 별이지만 빛나고 있어
# 7    8                             거꾸로 읽는 세계사
# 8    9                               NFT 레볼루션
# 9   10                             미드나잇 라이브러리
# 10  11                              거인의 포트폴리오
# 11  12                               하루공부 365
# 12  13                             달러구트 꿈 백화점
# 13  14                      내 영혼을 다독이는 관계 심리학
# 14  15                      인생의 변화는 말투에서 시작된다
# 15  16                               그냥, 그렇다고
# 16  17                          개미 5년, 세후 55억
# 17  18                                오은영의 화해
# 18  19                       김대리의 쉽게 뜨는 요즘 니트
# 19  20                       아무런 대가 없이 건네는 다정
# 20  21                               그냥 하지 말라
# 21  22                           달러구트 꿈 백화점 2
# 22  23                                날마다 만우절
# 23  24                              NFT 사용설명서
# 24  25                               눈치 없는 돌쇠
# 0    1                              귀멸의 칼날 외전
# 1    2                                    웰씽킹
# 2    3                          한 게으른 시인의 이야기
# 3    4                             거꾸로 읽는 세계사
# 4    5                       김대리의 쉽게 뜨는 요즘 니트
# 5    6                                  계절 산문
# 6    7                             도쿄 리벤저스 17
# 7    8                             도쿄 리벤저스 18
# 8    9                            소크라테스 익스프레스
# 9   10                           트렌드 코리아 2022
# 10  11                                이순신의 바다
# 11  12                                불편한 편의점
# 12  13                                   밝은 밤
# 13  14                              NFT 사용설명서
# 14  15            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 15  16                             달러구트 꿈 백화점
# 16  17                                체인소 맨 9
# 17  18                     요한 제바스티안 바흐 교회 칸타타
# 18  19                                라이온의 간식
# 19  20                          개미 5년, 세후 55억
# 20  21  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 21  22                               그냥 하지 말라
# 22  23                                오은영의 화해
# 23  24                           달러구트 꿈 백화점 2
# 24  25                        365일 명화 일력(스프링)
# 0    1                                불편한 편의점
# 1    2                           트렌드 코리아 2022
# 2    3                             거꾸로 읽는 세계사
# 3    4                                이순신의 바다
# 4    5                                 흔한남매 9
# 5    6                          개미 5년, 세후 55억
# 6    7                                리딩지저스 1
# 7    8                           달러구트 꿈 백화점 2
# 8    9                                오은영의 화해
# 9   10                            소크라테스 익스프레스
# 10  11                                    웰씽킹
# 11  12                         작은 별이지만 빛나고 있어
# 12  13                             달러구트 꿈 백화점
# 13  14                          종목 선정 나에게 물어봐
# 14  15                             미드나잇 라이브러리
# 15  16                              오십에 읽는 논어
# 16  17                              거인의 포트폴리오
# 17  18                              NFT 사용설명서
# 18  19                       아직 오지 않은 날들을 위하여
# 19  20                               NFT 레볼루션
# 20  21                           부자 아빠 가난한 아빠
# 21  22                               하루공부 365
# 22  23                        설민석의 세계사 대모험 11
# 23  24  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 24  25                             달러구트 꿈 백화점
# 0    1                                 흔한남매 9
# 1    2                           트렌드 코리아 2022
# 2    3                                불편한 편의점
# 3    4                             달러구트 꿈 백화점
# 4    5               오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 5    6                           흔한남매 겨울밤 대소동
# 6    7                             미드나잇 라이브러리
# 7    8                           달러구트 꿈 백화점 2
# 8    9                              오십에 읽는 논어
# 9   10                             거꾸로 읽는 세계사
# 10  11                               NFT 레볼루션
# 11  12                                원피스 100
# 12  13                                오은영의 화해
# 13  14                            소크라테스 익스프레스
# 14  15                                    웰씽킹
# 15  16                           부자 아빠 가난한 아빠
# 16  17                     햇빛은 찬란하고 인생은 귀하니까요
# 17  18                              귀멸의 칼날 외전
# 18  19                               크리스마스 피그
# 19  20                       이상한 과자 가게 전천당 12
# 20  21                           세계미래보고서 2022
# 21  22                               그냥 하지 말라
# 22  23                              거인의 포트폴리오
# 23  24                             달러구트 꿈 백화점
# 24  25                        이상한 과자 가게 전천당 1

# %%
# df_all 에서 책제목이 5개 이상있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() >= 5]
# df_all 에서 책제목이 4개 있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() == 4]
# df_all 에서 책제목이 3개 있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() == 3]
# df_all 에서 책제목이 2개 있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() == 2]
# df_all 에서 책제목이 1개 있는 것
df_all['책제목'].value_counts()[df_all['책제목'].value_counts() == 1]
# Out:
# 내 영혼을 다독이는 관계 심리학           1
# 달콩이네 떡집                     1
# 리딩지저스 1                     1
# 이상한 과자 가게 전천당 12            1
# 오늘 밤, 세계에서 이 사랑이 사라진다 해도    1
# 흔한남매 과학탐험대 3                1
# 도쿄 리벤저스 18                  1
# 도쿄 리벤저스 17                  1
# 크리스마스 피그                    1
# 체인소 맨 9                     1
# 네모아저씨의 페이퍼 블레이드 4 프런티어      1
# 요한 제바스티안 바흐 교회 칸타타          1
# 라이온의 간식                     1
# 눈치 없는 돌쇠                    1
# 원피스 100                     1
# 밝은 밤                        1
# 이상한 과자 가게 전천당 1             1
# 세계미래보고서 2022                1
# 눈아이                         1
# 어떻게 말해줘야 할까                 1
# 햇빛은 찬란하고 인생은 귀하니까요          1
# 날마다 만우절                     1
# 그냥, 그렇다고                    1
# 인생의 변화는 말투에서 시작된다           1
# 계절 산문                       1
# 아직 오지 않은 날들을 위하여            1
# 365일 명화 일력(스프링)             1
# 한 게으른 시인의 이야기               1
# 아무런 대가 없이 건네는 다정            1
# Name: 책제목, dtype: int64

# %%
[df_all['책제목'].value_counts() ==4 ]
# Out:
# [달러구트 꿈 백화점                               False
#  불편한 편의점                                  False
#  웰씽킹                                      False
#  거꾸로 읽는 세계사                               False
#  트렌드 코리아 2022                             False
#  오은영의 화해                                  False
#  소크라테스 익스프레스                              False
#  달러구트 꿈 백화점 2                             False
#  NFT 레볼루션                                  True
#  흔한남매 9                                    True
#  거인의 포트폴리오                                 True
#  개미 5년, 세후 55억                             True
#  미드나잇 라이브러리                                True
#  이순신의 바다                                   True
#  오십에 읽는 논어                                False
#  김대리의 쉽게 뜨는 요즘 니트                         False
#  그냥 하지 말라                                 False
#  NFT 사용설명서                                False
#  하루공부 365                                 False
#  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING    False
#  귀멸의 칼날 외전                                False
#  딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿              False
#  작은 별이지만 빛나고 있어                           False
#  부자 아빠 가난한 아빠                             False
#  흔한남매 겨울밤 대소동                             False
#  종목 선정 나에게 물어봐                            False
#  설민석의 세계사 대모험 11                          False
#  내 영혼을 다독이는 관계 심리학                        False
#  달콩이네 떡집                                  False
#  리딩지저스 1                                  False
#  이상한 과자 가게 전천당 12                         False
#  오늘 밤, 세계에서 이 사랑이 사라진다 해도                 False
#  흔한남매 과학탐험대 3                             False
#  도쿄 리벤저스 18                               False
#  도쿄 리벤저스 17                               False
#  크리스마스 피그                                 False
#  체인소 맨 9                                  False
#  네모아저씨의 페이퍼 블레이드 4 프런티어                   False
#  요한 제바스티안 바흐 교회 칸타타                       False
#  라이온의 간식                                  False
#  눈치 없는 돌쇠                                 False
#  원피스 100                                  False
#  밝은 밤                                     False
#  이상한 과자 가게 전천당 1                          False
#  세계미래보고서 2022                             False
#  눈아이                                      False
#  어떻게 말해줘야 할까                              False
#  햇빛은 찬란하고 인생은 귀하니까요                       False
#  날마다 만우절                                  False
#  그냥, 그렇다고                                 False
#  인생의 변화는 말투에서 시작된다                        False
#  계절 산문                                    False
#  아직 오지 않은 날들을 위하여                         False
#  365일 명화 일력(스프링)                          False
#  한 게으른 시인의 이야기                            False
#  아무런 대가 없이 건네는 다정                         False
#  Name: 책제목, dtype: bool]

# %%
df_all_title = []
df_all_rank = []

for i in df_all['책제목'].unique():
    mean = df_all['순위'][df_all['책제목'] == i].mean()
    df_all_title.append(i)
    df_all_rank.append(mean)
    rank.append(1)
dic = {'종합순위':df_all_rank, '책제목':df_all_title}
df = pd.DataFrame(dic)
df.set_index('종합순위', inplace=True)
pd.options.display.float_format = '{:.2f}'.format # 종합순위 반올림
df.sort_values('종합순위') # 오름차순 정렬
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-49150516b098> in <module>
#       6     df_all_title.append(i)
#       7     df_all_rank.append(mean)
# ----> 8     rank.append(1)
#       9 dic = {'종합순위':df_all_rank, '책제목':df_all_title}
#      10 df = pd.DataFrame(dic)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
df_all['순위'][df_all['책제목'] == '한 게으른 시인의 이야기']
# Out:
# 2    3
# Name: 순위, dtype: int64

# %%
# 베스트셀러 종합순위
df_all_title = []
df_all_rank = []

for i in df_all['책제목'].unique():
    if len(df_all['순위'][df_all['책제목'] == i]) == 1:
        mean = df_all['순위'][df_all['책제목'] == i].mean()+20
    elif len(df_all['순위'][df_all['책제목'] == i]) == 2:
        mean = df_all['순위'][df_all['책제목'] == i].mean()+15
    elif len(df_all['순위'][df_all['책제목'] == i]) == 3:
        mean = df_all['순위'][df_all['책제목'] == i].mean()+10
    elif len(df_all['순위'][df_all['책제목'] == i]) == 4:
        mean = df_all['순위'][df_all['책제목'] == i].mean()+5
    else : mean = df_all['순위'][df_all['책제목'] == i].mean()
    df_all_title.append(i)
    df_all_rank.append(mean)
dic = {'종합순위':df_all_rank, '책제목':df_all_title}
df = pd.DataFrame(dic)
df.set_index('종합순위')
pd.options.display.float_format = '{:.2f}'.format # 종합순위 반올림
df = df.sort_values('종합순위') # 오름차순 정렬
df
# Out:
#     종합순위                                    책제목
# 2   3.60                           트렌드 코리아 2022
# 3   4.40                                불편한 편의점
# 7   6.60                             거꾸로 읽는 세계사
# 5   7.80                                    웰씽킹
# 1   8.00                                 흔한남매 9
# 0  10.50                                이순신의 바다
# 17 10.80                            소크라테스 익스프레스
# 6  14.75                             미드나잇 라이브러리
# 11 14.80                           달러구트 꿈 백화점 2
# 12 15.20                                오은영의 화해
# 16 16.00                             달러구트 꿈 백화점
# 4  19.00                              거인의 포트폴리오
# 13 19.25                          개미 5년, 세후 55억
# 18 19.75                               NFT 레볼루션
# 9  23.00                           흔한남매 겨울밤 대소동
# 36 23.00                          한 게으른 시인의 이야기
# 25 24.50                         작은 별이지만 빛나고 있어
# 35 24.50                              귀멸의 칼날 외전
# 49 25.00               오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 21 25.67                              오십에 읽는 논어
# 22 25.67                       김대리의 쉽게 뜨는 요즘 니트
# 37 26.00                                  계절 산문
# 46 27.00                                리딩지저스 1
# 38 27.00                             도쿄 리벤저스 17
# 39 28.00                             도쿄 리벤저스 18
# 33 28.67                              NFT 사용설명서
# 8  29.00                 네모아저씨의 페이퍼 블레이드 4 프런티어
# 15 30.00                          종목 선정 나에게 물어봐
# 10 31.00                                달콩이네 떡집
# 31 31.67                               그냥 하지 말라
# 50 32.00                                원피스 100
# 26 32.00                               하루공부 365
# 40 33.00                                   밝은 밤
# 48 33.50                           부자 아빠 가난한 아빠
# 27 34.00                      내 영혼을 다독이는 관계 심리학
# 14 34.00                        설민석의 세계사 대모험 11
# 23 34.50            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 28 35.00                      인생의 변화는 말투에서 시작된다
# 29 36.00                               그냥, 그렇다고
# 51 37.00                     햇빛은 찬란하고 인생은 귀하니까요
# 41 37.00                                체인소 맨 9
# 44 37.50  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 42 38.00                     요한 제바스티안 바흐 교회 칸타타
# 47 39.00                       아직 오지 않은 날들을 위하여
# 52 39.00                               크리스마스 피그
# 43 39.00                                라이온의 간식
# 30 40.00                       아무런 대가 없이 건네는 다정
# 19 40.00                                    눈아이
# 53 40.00                       이상한 과자 가게 전천당 12
# 54 41.00                           세계미래보고서 2022
# 20 41.00                            어떻게 말해줘야 할까
# 32 43.00                                날마다 만우절
# 45 45.00                        365일 명화 일력(스프링)
# 24 45.00                           흔한남매 과학탐험대 3
# 34 45.00                               눈치 없는 돌쇠
# 55 45.00                        이상한 과자 가게 전천당 1

# %%
# 베스트 종합순위 최종
df['순위'] = df['종합순위'].rank()
pd.options.display.float_format = '{:.0f}'.format
df.set_index('순위', inplace=True)
del df['종합순위']
df
# Out:
#                                       책제목
# 순위
# 1                            트렌드 코리아 2022
# 2                                 불편한 편의점
# 3                              거꾸로 읽는 세계사
# 4                                     웰씽킹
# 5                                  흔한남매 9
# 6                                 이순신의 바다
# 7                             소크라테스 익스프레스
# 8                              미드나잇 라이브러리
# 9                            달러구트 꿈 백화점 2
# 10                                오은영의 화해
# 11                             달러구트 꿈 백화점
# 12                              거인의 포트폴리오
# 13                          개미 5년, 세후 55억
# 14                               NFT 레볼루션
# 16                           흔한남매 겨울밤 대소동
# 16                          한 게으른 시인의 이야기
# 18                         작은 별이지만 빛나고 있어
# 18                              귀멸의 칼날 외전
# 19               오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 20                              오십에 읽는 논어
# 20                       김대리의 쉽게 뜨는 요즘 니트
# 22                                  계절 산문
# 24                                리딩지저스 1
# 24                             도쿄 리벤저스 17
# 25                             도쿄 리벤저스 18
# 26                              NFT 사용설명서
# 27                 네모아저씨의 페이퍼 블레이드 4 프런티어
# 28                          종목 선정 나에게 물어봐
# 29                                달콩이네 떡집
# 30                               그냥 하지 말라
# 32                                원피스 100
# 32                               하루공부 365
# 33                                   밝은 밤
# 34                           부자 아빠 가난한 아빠
# 36                      내 영혼을 다독이는 관계 심리학
# 36                        설민석의 세계사 대모험 11
# 37            딱 2년 안에 무조건 돈 버는 부동산 투자 시크릿
# 38                      인생의 변화는 말투에서 시작된다
# 39                               그냥, 그렇다고
# 40                     햇빛은 찬란하고 인생은 귀하니까요
# 40                                체인소 맨 9
# 42  ETS 토익 정기시험 기출문제집 1000 Vol. 3 READING
# 43                     요한 제바스티안 바흐 교회 칸타타
# 45                       아직 오지 않은 날들을 위하여
# 45                               크리스마스 피그
# 45                                라이온의 간식
# 48                       아무런 대가 없이 건네는 다정
# 48                                    눈아이
# 48                       이상한 과자 가게 전천당 12
# 50                           세계미래보고서 2022
# 50                            어떻게 말해줘야 할까
# 52                                날마다 만우절
# 54                        365일 명화 일력(스프링)
# 54                           흔한남매 과학탐험대 3
# 54                               눈치 없는 돌쇠
# 54                        이상한 과자 가게 전천당 1
